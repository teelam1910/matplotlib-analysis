# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
#
# - After Calculating the final tumor volume of each mouse across four of the treatment regimens (Capomulin, Ramicane, Infubinol, and Ceftamin), it was found that only one outlier exhisted and that was under Infubinol. <br>
#
# - With the correlation coefficient being 0.84, very close to 1, this is an indication that there is a strong positive correlation between mouse weight and tumor volume. This means that as mouse weight increases, tumor volume tends to increase as well. <br>
#
# - Observation for Mouse l509 on the Capomulin Treatment: The tumor volume of mouse l509 initially increased from 45 mm³ to approximately 48 mm³. However, around day 25, there was a notable decrease in tumor volume to around 44 mm³. Subsequently, the tumor volume displayed a consistent pattern of initial increase followed by a significant decrease. Despite the end of study the mouse showing another increase in tumor, it utimately ended with the volumne of about 41mm³ meaning, for this particular mouse, the Capomulin Treatment had a positive effect.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
# import numpy as np #this is not a part of the original import

# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# Combine the data into a single DataFrame
#mdc- mouse data complete
mdc = study_results.merge(mouse_metadata,on='Mouse ID')

# Display the data table for preview
mdc.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice.
mdc['Mouse ID'].nunique()
# Out:
# 249

# %%
# Our data should be uniquely identified by Mouse ID and Timepoint
# Get the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
mdc[mdc.duplicated(['Mouse ID', 'Timepoint'])]['Mouse ID'].unique()
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
mdc[mdc['Mouse ID']== 'g989']
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# 871     g989         30           59.082294                 1     Propriva
# 872     g989         35           62.570880                 2     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# 862  Female          21          26
# 863  Female          21          26
# 864  Female          21          26
# 865  Female          21          26
# 866  Female          21          26
# 867  Female          21          26
# 868  Female          21          26
# 869  Female          21          26
# 870  Female          21          26
# 871  Female          21          26
# 872  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean = mdc[mdc['Mouse ID'] != 'g989']
clean.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice in the clean DataFrame.
clean['Mouse ID'].nunique()
clean
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1     Female           9          22
# 2     Female           9          22
# 3     Female           9          22
# 4     Female           9          22
# ...      ...         ...         ...
# 1888    Male          22          17
# 1889    Male          22          17
# 1890    Male          22          17
# 1891    Male          22          17
# 1892    Male          22          17
#
# [1880 rows x 8 columns]

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
grp = clean.groupby('Drug Regimen')['Tumor Volume (mm3)']

# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 
# Assemble the resulting series into a single summary DataFrame.
pd.DataFrame({
    'Mean Tumor Volume': grp.mean(),
    'Median Tumor Volume': grp.median(),
    'Tumor Volume Variance': grp.var(),
    'Tumor Volume Std. Dev.': grp.std(),
    'Tumor Volume Std. Err.': grp.sem()
})
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Tumor Volume Variance  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Tumor Volume Std. Dev.  Tumor Volume Std. Err.
# Drug Regimen
# Capomulin                   4.994774                0.329346
# Ceftamin                    6.268188                0.469821
# Infubinol                   6.567243                0.492236
# Ketapril                    8.279709                0.603860
# Naftisol                    8.134708                0.596466
# Placebo                     7.821003                0.581331
# Propriva                    6.622085                0.544332
# Ramicane                    4.846308                0.320955
# Stelasyn                    7.710419                0.573111
# Zoniferol                   6.966589                0.516398

# %%
grp = clean.groupby('Drug Regimen')[['Tumor Volume (mm3)']]

# %%
# A more advanced method to generate a summary statistics table of mean, median, variance, standard deviation,
# and SEM of the tumor volume for each regimen (only one method is required in the solution)

# Using the aggregation method, produce the same summary statistics in a single line
# look for method to create title using a dictionary
grp.agg(['mean', 'median', 'var', 'std', 'sem'])
# grp.aggregate()
# Out:
#              Tumor Volume (mm3)
#                            mean     median        var       std       sem
# Drug Regimen
# Capomulin             40.675741  41.557809  24.947764  4.994774  0.329346
# Ceftamin              52.591172  51.776157  39.290177  6.268188  0.469821
# Infubinol             52.884795  51.820584  43.128684  6.567243  0.492236
# Ketapril              55.235638  53.698743  68.553577  8.279709  0.603860
# Naftisol              54.331565  52.509285  66.173479  8.134708  0.596466
# Placebo               54.033581  52.288934  61.168083  7.821003  0.581331
# Propriva              52.320930  50.446266  43.852013  6.622085  0.544332
# Ramicane              40.216745  40.673236  23.486704  4.846308  0.320955
# Stelasyn              54.233149  52.431737  59.450562  7.710419  0.573111
# Zoniferol             53.236507  51.818479  48.533355  6.966589  0.516398

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using Pandas.
# X-axis= Drug Regimen, Y-axis =# of Observed Mouse Timepoints
# Use clean df

regimen_counts = clean.groupby('Drug Regimen').size().sort_values(ascending=False)
regimen_counts.plot(kind='bar', 
                    color='steelblue', 
                    #figsize=[16,3],
                    xlabel='Drug Regimen', 
                    ylabel='# of Observed Mouse Timepoints');

# %%
# Generate a bar plot showing the total number of rows (Mouse ID/Timepoints) for each drug regimen using pyplot.
# Use a series

plt.bar(x = regimen_counts.index, height = regimen_counts)

plt.xlabel('Drug Regimen')
plt.ylabel('# of Observed Mouse Timepoints')

plt.xticks(rotation=90)

plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas
p_data = clean.Sex.value_counts()
p_data.plot.pie(autopct='%.2f%%');

# %%
p_data.index
# Out:
# Index(['Male', 'Female'], dtype='object')

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
plt.pie(p_data, labels = p_data.index, autopct='%.2f%%') #,colors = ['blue','pink'])
plt.ylabel('Sex')

plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin
# Start by getting the last (greatest) timepoint for each mouse
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
# Put treatments into a list for for loop (and later for plot labels)
# Create empty list to fill with tumor vol data (for plotting)
# Calculate the IQR and quantitatively determine if there are any potential outliers. 
   
    # Locate the rows which contain mice on each drug and get the tumor volumes
    # add subset 
    # Determine outliers using upper and lower bounds


tumor_df = clean.groupby('Mouse ID').Timepoint.max().reset_index().merge(clean,on=['Mouse ID', 'Timepoint'])
drugs = ['Capomulin', 'Ramicane', 'Infubinol','Ceftamin']

tumor_list = []

for drug in drugs:
    tumor = tumor_df[tumor_df['Drug Regimen']==drug]['Tumor Volume (mm3)']
    tumor_list.append(tumor)
    
    iqr = tumor.quantile(.75) - tumor.quantile(.25)
    lower = tumor.quantile(.25) - 1.5*iqr
    upper = tumor.quantile(.75) + 1.5*iqr
    
    print(f"{drug}'s potential outliers: {tumor[(tumor<lower)|(tumor>upper)]}")
# Out:
# Capomulin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Ramicane's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)
# Infubinol's potential outliers: 31    36.321346
# Name: Tumor Volume (mm3), dtype: float64
# Ceftamin's potential outliers: Series([], Name: Tumor Volume (mm3), dtype: float64)

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
plt.ylabel("Final Tumor Volume (mm3)")
plt.boxplot(tumor_list,labels=drugs,flierprops={'marker':'o','markersize':12,'markerfacecolor':'red'});

# %% [markdown]
# ## Line and Scatter Plots

# %%
clean[clean['Mouse ID']=='l509']
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 1721     l509          0           45.000000                 0    Capomulin
# 1722     l509          5           45.851193                 0    Capomulin
# 1723     l509         10           46.759074                 0    Capomulin
# 1724     l509         15           47.488599                 1    Capomulin
# 1725     l509         20           48.070452                 2    Capomulin
# 1726     l509         25           44.006257                 2    Capomulin
# 1727     l509         30           44.708055                 2    Capomulin
# 1728     l509         35           40.207288                 2    Capomulin
# 1729     l509         40           40.770813                 2    Capomulin
# 1730     l509         45           41.483008                 3    Capomulin
#
#        Sex  Age_months  Weight (g)
# 1721  Male          17          21
# 1722  Male          17          21
# 1723  Male          17          21
# 1724  Male          17          21
# 1725  Male          17          21
# 1726  Male          17          21
# 1727  Male          17          21
# 1728  Male          17          21
# 1729  Male          17          21
# 1730  Male          17          21

# %%
# Generate a line plot of tumor volume vs. time point for a single mouse treated with Capomulin

capomulin = clean.loc[clean['Drug Regimen'] == 'Capomulin']
mouse = capomulin.loc[capomulin['Mouse ID'] == 'l509']
timepoint = mouse['Timepoint']
tumor_volume = mouse['Tumor Volume (mm3)']
mouse_id = 'l509'


plt.plot(timepoint, tumor_volume)

plt.xlabel('Timepoint (Days)')
plt.ylabel('Tumor Volume (mm3)')
plt.title(f'Capomulin Treatment of Mouse {mouse_id}')

plt.show()

# %%
# Generate a scatter plot of mouse weight vs. the average observed tumor volume for the entire Capomulin regimen

# capomulin = clean[clean['Drug Regimen'] == 'Capomulin']
avg_tumor = capomulin.groupby('Mouse ID')[['Weight (g)','Tumor Volume (mm3)']].mean()


plt.scatter(avg_tumor['Weight (g)'], avg_tumor['Tumor Volume (mm3)'], marker='o')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and a linear regression model 
# for mouse weight and average observed tumor volume for the entire Capomulin regimen


mouse_weight = avg_tumor['Weight (g)']
cor_co = cor_co = st.pearsonr(mouse_weight, tumor_volume)[0]


# Linear regression 
slope, intercept, _, _, _ = st.linregress(mouse_weight, tumor_volume)

plt.scatter(mouse_weight, tumor_volume, marker='o', label='Data')
plt.xlabel('Weight (g)')
plt.ylabel('Average Tumor Volume (mm3)')
plt.title('Average Tumor Volume vs. Weight')

# Regression Line
plt.plot(mouse_weight, slope * mouse_weight + intercept, color='red', label='Linear Regression')

plt.legend()
plt.show()



print("Correlation Coefficient:", cor_co)
print("Slope:", slope)
print("Intercept:", intercept)
# Out:
# Correlation Coefficient: 0.8419363424694721
# Slope: 0.9544396890241049
# Intercept: 21.552160532685008
